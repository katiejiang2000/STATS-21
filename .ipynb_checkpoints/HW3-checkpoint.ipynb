# %% [markdown]
# # Stats 21 - HW 3

# %% [markdown]
# Homework copyright Miles Chen. Problems have been adapted from th exercises in Think Python 2nd Ed by Allen B. Downey.
#
# This is your third homework assignment.
#
# The questions have been entered into this document. You will modify the document by entering your code.
#
# Make sure you run the cell so the requested output is visible. Download the finished document as either a PDF or an HTML file.
#
# You will submit:
#
# - the rendered HTML/PDF file
# - this ipynb file with your answers

# %% [markdown]
# ## Reading
#
# - Chapters 7 to 11
#
# Please keep up with the reading. The chapters are short.
#
# More reading:
#
# - String methods documentation https://docs.python.org/3/library/stdtypes.html#string-methods

# %% [markdown]
# ### Exercise 8.3
#
# A string slice can take a third index that speciﬁes the "step size"; that is, the number of spaces between successive characters. A step size of 2 means every other character; 3 means every
# third, etc. You can even have negative values.
#
# Use a string slice to create a one line function for `is_palindrome()`

# %%
def is_palindrome(text):
    return text == text[::-1]

# %%
is_palindrome("racecar")
# Out:
# True

# %%
is_palindrome("racecars")
# Out:
# False

# %% [markdown]
# ## Chapter 9
#
# The following exercises have been adapted from Think Python.

# %% [markdown]
# ### Exercise 9.1
#
# Download this list of words: http://thinkpython2.com/code/words.txt
#
# Write and run a script that reads `words.txt` and prints out only the words with more than 20
# characters (after stripping whitespace).

# %%
fin = open("words.txt")
for line in fin:
    word = line.strip()
    if len(word) > 20:
        print(word)
# Out:
# counterdemonstrations
# hyperaggressivenesses
# microminiaturizations

# %% [markdown]
# ### Exercise 9.2
#
# Write a function called `has_no_e` that returns True if the word doesn't have the letter e. You can use any of Pythons availble string methods.

# %%
def has_no_e(text):
    return 'e' not in text

# %%
has_no_e("hello")
# Out:
# False

# %%
has_no_e("quit")
# Out:
# True

# %% [markdown]
# With your function, write a script. The script should read the list of words (`words.txt`), print out the number of words that do not have the letter 'e' and the proportion of words that do not have the letter 'e'

# %%
fin = open("words.txt")
noEWordsCount = 0 # Running total of words without 'e'
wordCount = 0 # Running total word count
for line in fin:
    word = line.strip()
    if has_no_e(word):
        noEWordsCount += 1
    wordCount += 1
print(noEWordsCount)
print(noEWordsCount / wordCount) # Proportion as a decimal
# Out:
# 37641
# 0.3307383423103621

# %% [markdown]
# ### Exercise 9.3
#
# Write a function named `avoids` that takes a word and a string of forbidden letters, and that returns True if the word doesn’t use any of the forbidden letters.

# %%
def avoids(word, forbidden):
    for letter in forbidden:
        if letter in word:
            return False
    return True

# %%
avoids("hello", "e")
# Out:
# False

# %%
avoids("hello", "abc")
# Out:
# True

# %%
avoids("hello", "abcde")
# Out:
# False

# %% [markdown]
# Write a function named `prop_avoiding` that accepts a string of forbidden letters and then returns the proportion of words that don’t contain any of them.

# %%
def prop_avoiding(forbidden):
    
    avoidingWordCount = 0
    wordCount = 0
    fin = open("words.txt")
    
    for line in fin:
        word = line.strip()
        if avoids(word, forbidden):
            avoidingWordCount += 1
        wordCount += 1    
        
    return avoidingWordCount / wordCount

# %%
prop_avoiding("e")
# Out:
# 0.3307383423103621

# %% [markdown]
# Write a short script that prints the letters a-z and the proportion of words that avoid that letter.

# %%
for letter in 'abcdefghijklmnopqrstuvwxyz':
    print(letter, str(prop_avoiding(letter)))
# Out:
# a 0.5025613088595805
# b 0.8567336502385576
# c 0.732305880905728
# d 0.7307067103656125
# e 0.3307383423103621
# f 0.9009129330720769
# g 0.7805182366948132
# h 0.8322101064063475
# i 0.47004191232679315
# j 0.9846497201451555
# k 0.9211134444551837
# l 0.6473653226019032
# m 0.802528798249699
# n 0.5634615891537577
# o 0.607614512033319
# p 0.7981794058466378
# q 0.9856601850468768
# r 0.517604055918249
# s 0.43059863455438496
# t 0.5845759122740732
# u 0.7462854431547593
# v 0.9218690964686448
# w 0.9273519668918978
# x 0.9763551212997215
# y 0.8845346150128724
# z 0.9696772662970415

# %% [markdown]
# ### Exercise 9.4.
#
# Write a function named `uses_only` that takes a word and a string of letters, and that returns True if the word contains only letters in the list.

# %%
def uses_only(word, allowed):
    for letter in word:
        if letter not in allowed:
            return False
    return True

# %% [markdown]
# Write a function to find all the words that use only the letters provided.

# %%
def find_all_allowed(allowed):
    '''allowed is a string of characters
    the function will print all words that use only allowed letters'''
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        if uses_only(word, allowed) and len(word) > 8:
            # I added this second condition to make sure that when I call it in the next cell, it'll only print a
            # few of the longest words. Otherwise, you would not need `and len(strippedLine) > 8` for this function.
            print(word)

# %% [markdown]
# Now use the function to find all the words that can be made out of the letters in your first (given) name and/or your last (family) name.
#
# DO NOT PRINT out the entire list of words. For some of you, the print out will be way too long. Just find a few of the longest or most interesting words in the list.

# %%
find_all_allowed('katiejiang')
# Out:
# agitating
# attaining
# attainting
# initiating
# kittening
# neatening
# tenanting

# %% [markdown]
# ### Exercise 9.5.
#
# Write a function named `uses_all` that takes a word and a string of required letters,
# and that returns `True` if the word uses all the required letters at least once.
#
# Find and print the shortest words that uses all the vowels aeiou.
#
# Find and print the shortest words that uses all the vowels and y aeiouy.

# %%
def uses_all(word, required):
    useOfRequiredLetters = []
    for requiredLetter in required:
        # Append a bool value to the list, that denotes whether or not the letter is used in the word.
        useOfRequiredLetters.append(requiredLetter in word)
        # The list will contain a bool value for each letter in `required`.
    return all(useOfRequiredLetters)

# %%
uses_all("hello", "hel")
# Out:
# True

# %%
fin = open('words.txt')
for line in fin:
    word = line.strip()
    if uses_all(word, 'aeiou') and len(word) < 8:
        # I added this second condition to make sure that it'll only print the shortest words.
        print(word)
# Out:
# eulogia
# miaoued
# sequoia

# %%
fin = open('words.txt')
for line in fin:
    word = line.strip()
    if uses_all(word, 'aeiouy') and len(word) < 11:
        # Again, I added this second condition to make sure that it'll only print the shortest words.
        print(word)
# Out:
# autotypies
# buoyancies

# %% [markdown]
# ### Your choice: Exercise 9.7 - 9.9
#
# Choose one of the "car talk" puzzles at the end of Chapter 9. The puzzles are all very well defined. Some of the solutions can be found by just "thinking" about the puzzle, but the purpose of the exercise is to find the solution with a bit of script programming.
#
# I know the solutions are already provided on the book's website. I promise, you will get much more out of the experience and find much more satisfaction if you write the code yourself.
#
# They can be fun to solve and you are welcome to do all three of them if you wish, but I will not be giving extra credit for the additional effort.

# %%
# Exercise 9.7

fin = open('words.txt')

for line in fin:
    word = line.strip()
    if len(word) >= 6: # For the word to have three consecutive pairs, it must be at least 6 characters long.
        for i in range(len(word) - 5):
            if word[i] == word[i+1]: # First pair
                j = i + 2
                if word[j] == word[j+1]: # Second pair
                    k = j + 2
                    if word[k] == word[k+1]: # Third pair
                        print(word)
                        break
# Out:
# bookkeeper
# bookkeepers
# bookkeeping
# bookkeepings

# %% [markdown]
# If you find yourself truly stuck, set it aside and think about it for a day. The answer might come to you while you are not sitting in front of your computer.
#
# If you're still truly truly stuck, you can take a peek at the answer to see how it is done. Then set it aside, don't write any code for a day. Then code up the answer with the framework in mind, but not the code itself.

# %% [markdown]
# ### Exercise 10.1.
#
# Write a function called `nested_sum` that takes a list of lists of integers and adds up
# the elements from all of the nested lists. For example:
# ```
# t = [[1, 2], [3], [4, 5, 6]]
# nested_sum(t)
# 21
# ```
# You may want to build the function recursively in case there are many levels of nested lists.
#
# You can assume that all elements in any of the nested lists are numeric.

# %%
def nested_sum(t):
    if type(t) == int:
        return t
    else:
        theSum = 0
        for element in t:
            theSum += nested_sum(element)
    return theSum

# %%
t = [1, 2]
nested_sum(t)
# Out:
# 3

# %%
t = [[1, 2], [3], [4, 5, 6]]
nested_sum(t)
# Out:
# 21

# %%
x = [[1, 2, [3]], 4, 5, 6, [7], 8]
nested_sum(x)
# Out:
# 36

# %%
t = [[[1, 2, [3]], [4, [5, 6, [7]], 8]]]
nested_sum(t)
# Out:
# 36

# %% [markdown]
# ### Exercise 10.2.
#
# Write a function called `cumsum` that takes a list of numbers and returns the cumulative sum; that is, a new list where the ith element is the sum of the first i + 1 elements from the original list.
#
# For example:
# ```
# t = [1, 2, 3]
# cumsum(t)
# [1, 3, 6]
# ```
#
# You can assume that all elements in the lists are numeric and the list does not contain nested lists.

# %%
def cumsum(t):
    result = []
    for idx in range(len(t)):
        result.append(sum(t[0:idx+1]))
    return result

# %%
cumsum([1, 2, 3, 4])
# Out:
# [1, 3, 6, 10]

# %%
cumsum(range(12))
# Out:
# [0, 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66]

# %% [markdown]
# ### Exercise 10.6.
#
# Two words are anagrams if you can rearrange the letters from one to spell the other. Write a function called `is_anagram` that takes two strings and returns `True` if they are anagrams.
#
# You can remove spaces and convert to lowercase using `string.replace(" ","").lower()`

# %%
def is_anagram(word1, word2):
    word1Clean = word1.replace(" ", "").lower()
    word2Clean = word2.replace(" ", "").lower()
    for letter1 in word1Clean:
        if letter1 not in word2Clean:
            return False
    for letter2 in word2Clean:
        if letter2 not in word1Clean:
            return False
    return True

# %%
is_anagram("hello", "o hell")
# Out:
# True

# %%
is_anagram("dormitory" , "dirty room")
# Out:
# True

# %%
is_anagram("dormitory" , "dirty rooms")
# Out:
# False

# %%
is_anagram("astronomers" , "moon starers")
# Out:
# True

# %% [markdown]
# ### Exercise 10.7.
#
# Write a function called `has_duplicates` that takes a list and returns `True` if there is any element that appears more than once. It should not modify the original list.
#
# You can assume that the list will not have nested lists.

# %%
def has_duplicates(t):
    uniqueVals = []
    for element in t:
        if element in uniqueVals:
            return True
        else:
            uniqueVals.append(element)
    return False

# %%
has_duplicates(['a','b','c'])
# Out:
# False

# %%
has_duplicates(['a','b','b','c'])
# Out:
# True

# %%
has_duplicates(['a','b','c','a'])
# Out:
# True

# %% [markdown]
# ### Exercise 10.10.
#
# To check whether a word is in the word list, you could use the in operator, but it would be slow because it searches through the words in order.
#
# Because the words are in alphabetical order, we can speed things up with a bisection search (also known as binary search). You start in the middle and check to see whether the word you are looking for comes before the word in the middle of the list. If so, you search the first half of the list the same way (perform a bisection search on the first half). Otherwise you search the second half.
#
# Either way, you cut the remaining search space in half. If the word list has 113,809 words, it will
# take about 17 steps to find the word or conclude that it's not there.
#
# Write a function called `in_bisect` that takes a sorted list and a target word and will returns `True` if the word is in the list and `False` if it's not.
#
# Hint: it's a recursive function.

# %%
# Use this function. No need to rewrite it.
def make_word_list():
    """Reads lines from a file and builds a list."""
    t = []
    fin = open('words.txt')
    for line in fin:
        word = line.strip()
        t.append(word)
    return t

t = make_word_list()

# %%
# define this function
def in_bisect(word_list, word):
    
    # Base case
    if len(word_list) == 1:
        return word_list[0] == word
    
    # Recursive call
    halfway = len(word_list) // 2
    halfwayWord = word_list[halfway]
    if word == halfwayWord:
        return True
    elif word < halfwayWord:
        # search first half
        return in_bisect(word_list[:halfway], word)
    elif word > halfwayWord:
        # search second half
        return in_bisect(word_list[halfway:], word)

# %%
in_bisect(t, "hello")
# Out:
# True

# %%
in_bisect(t, "xyz")
# Out:
# False

# %% [markdown]
# ### Exercise 10.11
#
# Two words are a "reverse pair" if each is the reverse of the other.
#
# Now that you have the `in_bisect` search, write a script that ﬁnds all the reverse pairs in the word list that are 6 letters or longer. (It takes a little bit of time to run.)

# %%
fin = open('words.txt')

# Clean the strings in words.txt and convert to sorted list, so that it can be passed into in_bisect()
finList = []
for line in fin:
    word = line.strip()
    finList.append(word)
finList.sort()

# Iterate through finList looking for reverse pairs and printing them when found.
for word in finList:
    reverseWord = word[::-1]
    if len(word) >= 6 and in_bisect(finList, reverseWord):
        print(word, reverseWord)
# Out:
# agenes senega
# animal lamina
# animes semina
# degami imaged
# deified deified
# deifier reified
# deliver reviled
# denier reined
# denies seined
# denned denned
# depots stoped
# derats stared
# dessert tressed
# desserts stressed
# dewans snawed
# dialer relaid
# diaper repaid
# dormin nimrod
# drawer reward
# elides sedile
# eviler relive
# gelder redleg
# halalah halalah
# hallah hallah
# imaged degami
# lamina animal
# levins snivel
# looter retool
# marram marram
# nimrod dormin
# pupils slipup
# recaps spacer
# redder redder
# redips spider
# redleg gelder
# redraw warder
# redrawer rewarder
# reflet telfer
# reflow wolfer
# reified deifier
# reifier reifier
# reined denier
# reknit tinker
# reknits stinker
# relaid dialer
# relive eviler
# remeet teemer
# rennet tenner
# repaid diaper
# repaper repaper
# repins sniper
# retool looter
# reviled deliver
# reviver reviver
# reward drawer
# rewarder redrawer
# rotator rotator
# sallets stellas
# scares seracs
# secret terces
# ...

# %% [markdown]
# ### Exercise 11.1
#
# Write a function that reads the words in words.txt and stores them as keys in a dictionary. It doesn't matter what the values are. Then you can use the in operator as a fast way to
# check whether a string is in the dictionary.
#
# Do Exercise 10.10 but this time searching the dictionary using the `in` operator. You can see how much faster it is to search a dictionary.

# %%
def make_word_dict():
    fin = open('words.txt')
    d = {}
    for line in fin:
        word = line.strip()
        d[word] = ''
    return d
        
t = make_word_dict()

# %%
'hello' in t
# Out:
# True

# %%
'xyz' in t
# Out:
# False

# %% [markdown]
# ### Exercise 12.2
#
# 1. Write a program that reads a word list from a ﬁle (see Section 9.1) and prints all the sets of words that are anagrams. Here is an example of what the output might look like:
#
# ~~~
# ['deltas','desalt','lasted','salted','slated','staled']
# ['retainers','ternaries']
# ['generating','greatening']
# ['resmelts','smelters','termless']
# ~~~
#
# Hint:
# First traverse the entire wordlist to build a dictionary that maps from a collection of letters to a list of words that can be spelled with those letters. The question is, how can you represent the collection of letters in a way that can be used as a key? i.e. The word "eat" and the word "tea" should be in a list associated with a key ('a','e','t').
#
# When your script prints the anagram list, have it prints the longest list of anagrams first, followed by the second longest, and so on.

# %%
fin = open('words.txt')
wordlist = []
for line in fin:
    word = line.strip()
    wordlist.append(word)
    
combos = {}
for word in wordlist:
    letters = []
    for letter in word:
        letters.append(letter)
    letters.sort()
    letters = tuple(letters)
    if letters not in combos:
        updatedItem = {letters: [word]}
        combos.update(updatedItem)
    else:
        updatedValue = []
        for x in combos[letters]:
            updatedValue.append(x)
        updatedValue.append(word)
        combos[letters] = updatedValue
        
anagrams = {} # Key = length of the anagram list; Value = anagram list(s)
for anagramList in combos.values():
    anagramListLength = len(anagramList)
    if anagramListLength > 1:
        # Add the anagram to anagrams.
        if anagramListLength not in anagrams:
            # Add new entry
            anagrams[anagramListLength] = [anagramList]
        else:
            # Update existing entry
            updatedValue = []
            for x in anagrams[anagramListLength]:
                updatedValue.append(x)
            updatedValue.append(anagramList)
            anagrams[anagramListLength] = updatedValue

for anagramListLength in sorted(anagrams, reverse = True):
    for anagramList in anagrams[anagramListLength]:
        print(anagramList)
# Out:
# ['alerts', 'alters', 'artels', 'estral', 'laster', 'ratels', 'salter', 'slater', 'staler', 'stelar', 'talers']
# ['apers', 'asper', 'pares', 'parse', 'pears', 'prase', 'presa', 'rapes', 'reaps', 'spare', 'spear']
# ['least', 'setal', 'slate', 'stale', 'steal', 'stela', 'taels', 'tales', 'teals', 'tesla']
# ['capers', 'crapes', 'escarp', 'pacers', 'parsec', 'recaps', 'scrape', 'secpar', 'spacer']
# ['estrin', 'inerts', 'insert', 'inters', 'niters', 'nitres', 'sinter', 'triens', 'trines']
# ['acers', 'acres', 'cares', 'carse', 'escar', 'races', 'scare', 'serac']
# ['anestri', 'nastier', 'ratines', 'retains', 'retinas', 'retsina', 'stainer', 'stearin']
# ['arles', 'earls', 'lares', 'laser', 'lears', 'rales', 'reals', 'seral']
# ['aspers', 'parses', 'passer', 'prases', 'repass', 'spares', 'sparse', 'spears']
# ['ates', 'east', 'eats', 'etas', 'sate', 'seat', 'seta', 'teas']
# ['carets', 'cartes', 'caster', 'caters', 'crates', 'reacts', 'recast', 'traces']
# ...
